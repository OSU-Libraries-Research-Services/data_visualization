# %% [markdown]
# # Python—Mastering the Basics
# # Session 1

# %% [markdown]
# ## Learning objectives
# 1. Contruct variables, manipulate strings, and loop through lists
# 2. Build and navigate dictionaries
# 3. Define and use functions
# 3. Export data to .csv files
#
# # Absolute vs relative paths
# When you run a Python script the folder it runs from is set as the **current working directory (cwd)**. This is where Python looks for files to read and write by default.
# - In **Jupyter Lab**, navigate to your project folder. Open or create a file in your project folder, and Python will treat that location as the base for storing and accessing files.
# - In **VS Code**, set the working directory by clicking the **Explorer** icon on the top left of the Activity Bar.
# - In **Spyder**, set the working directory by clicking the **folder icon** in the upper right corner of the Toolbar.
#
# ## Relative paths
# If your files are stored in the same folder as your Python script, you can use a **relative path**.
#
# :::{code-block}
# relative_filepath_of_text = "path.txt"
# :::
#
# Python interprets this path relative to the current working directory.
#
# ## Absolute paths
# If your files are stored elsewhere, use an **absolute path** to specify the full location:
#
# :::{code-block}
# absolute_filepath_of_text = "C:/path/to/your/directory/file.txt"
# :::
#
#
# ```{admonition} Exercise 1: Relative vs. Absolute Path
# :class: sidebar note
# :icon: False
# Write an relative and an absolute path to the `carmen_ohio.txt` file in your data folder
#
# ```

# %%
#relative path
carmen_relative_path='INSERT RELATIVE PATH HERE'

#absolute  path
carmen_absolute_path='INSERT ABSOLUTE PATH HERE'

# %% [markdown]
# # Reading and writing files
# ## Opening a file
# To work with a file in Python, you first need to **open** it. This returns a file object that allows you to read from or write to the file.
#
# **Basic Syntax:**
# :::{code-block}
# open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)
# :::
#
# - **file**: The path to the file (absolute or relative).
# - **mode**: Optional. Specifies how the file is opened. Default is `r` (read mode).
#
# ## Common file modes
#
# | **Character** | **Meaning**                                                                                   |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `'r'`         | open for reading (default)                                                                               |
# | `'w'`         | open for writing, truncating the file first
# | `'x'`         | open for exclusive creation, failing if the file already exists
# | `'a'`         | open for writing, appending to the end of file if it exists     |
# | `'b'`      | binary mode          |
# | `'t'`          | text mode (default) |
# | `'+'`         | open for updating (reading and writing |
#
# ## Encoding
# Use the encoding parameter when working in **text mode** to specify how characters are interpreted. Common encodings include:
#   - **utf-8** — Most commonly used and recommended.
#   - **utf-16** — Uses 2 bytes per character; useful for some international text.
#   - **utf-32** — Uses 4 bytes per character; supports all Unicode characters directly.
#
# ```{admonition} Exercise 2: Open in read mode
# :class: sidebar note
# :icon: False
# Open `carmen_ohio.txt` for reading, using the utf-8 encoding.
#
# ```

# %%
carmen_ohio='INSERT CODE HERE'
print(carmen_ohio)

# %% [markdown]
# ## Reading a file
# To read a file, open it in read mode (`r`) and use the `.read()` method
#
# ```{admonition} Exercise 3: Open in read mode for reading
# :class: sidebar note
# :icon: False
# Open `carmen_ohio.txt` for reading, using the utf-8 encoding and ask Python to read the file.
#
# ```

# %%
carmen_ohio='INSERT CODE HERE'
print(carmen_ohio)

# %% [markdown]
# :::{seealso} Alternative
# :class: dropdown
#
# Alternative - use a with block to open in read mode and use the .read() method
#
# ```{code-block} python
# with open('carmen_ohio.text', mode='r', encoding='utf-8') as file:
#     content = file.read()
#
# ```
#
# :::

# %% [markdown]
# ## Writing to a file
# To write a file, open it in write mode (`w`). This will **overwrite** the file if it already exists.
#
# If you don't specify a mode, Python defaults to `r` (read mode), so it's important to explicity set `mode='w'` when writing.
# :::{tip}
# To avoid accidentally overwriting your original file, consider renaming the output file before writing to it.
# :::
#
# ```{admonition} Exercise 4: Open in write mode
# :class: sidebar note
# :icon: False
# Open `carmen_ohio_revised.txt` in write mode, using the utf-8 encoding.
#
# ```

# %%
#open carmen_ohio_revised.txt in write mode, using the utf-8 encoding

# %% [markdown]
# Again, this creates an object. To add text to a file, use the .write() method.
#
# ```{admonition} Exercise 5: Write sentence to file
# :class: sidebar note
# :icon: False
# Add the text "Let's firm thy friendship again!!!" to carmen_ohio_revised.txt using the .write() method
#
# ```

# %%
#Let's firm thy friendship again!!! Add text to carmen_ohio_revised.txt using the .write() method

# %% [markdown]
# Now our file reads:

# %%
open('carmen_ohio_revised.txt', mode='r', encoding='utf-8').read()

# %% [markdown]
# :::{seealso} Alternative
# :class: dropdown
#
# Alternative - use a with block to open in write mode and use the .write() method
#
# ```{code-block} python
# with open('carmen_ohio_revised.txt', mode='w', encoding='utf-8') as file:
#     file.write("Let's firm thy friendship again!!!")
#
# ```
#
# :::

# %% [markdown]
# # Variables
#
# Python supports a variety of built-in data types, each suited for different kinds of information.
#
# :::{table}
# :label: table
# :align: center
#
# |     Name      | Abbr  |   Type   |          Description         |                                  Example                                  |
# |:--------------|:----- |:-------- |:---------------------------- | :------------------------------------------------------------------------ |
# |**String**     |str    | Sequence |Text                          | "The Ohio State University"                                               |
# |**Integer**    |int    | Numeric  |Whole numbers                 | 1870                                                                      |
# |**Float**      |float  | Numeric  |Decimal numbers               | 3.14                                                                      |
# |**Boolean**    |bool   | Boolean  |True/False values             | True                                                                      |
# |**List**       |list   | Sequence |Ordered, mutable collection   | ["The Ohio State University" , 1870 ]                                     |
# |**Dictionary** |dict   | Mapping  |Key-value pairs               | {"institution_name" : "The Ohio State University","year_founded" : 1870 } |
# |**Tuple**      |tuple  | Sequence |Ordered, immutable collection | ("The Ohio State University", 1870)                                       |
#
# :::
#
# - **Mutuable types**: Lists, dictionaries, and strings can be modified after creation.
# - **Immutable types**: Tuples cannot be changed once defined.
#
# ## Working with variables
# **Variables** are created using the  `=` operator.

# %%
institution_name = "The Ohio State University"
year_founded = 1870
university_facts = {"institution_name": "The Ohio State University", "year_founded" : 1870, "school_colors" : "scarlet & grey", "mascot" : "Brutus Buckeye", "students" : 60046, "endowment": 7.9 }
fact_list = ["The Ohio State University", 1870, "scarlet & grey","Brutus Buckeye", 60046, 7.9 ]

# %% [markdown]
# ### Naming rules
# - Can  include letters, digits, and underscores.
# - Must **not** start with a digit.
# - Cannot contain spaces or special characthers (except _).
# - Must **not** use reserved Python keywords.
#
# ### Reserved keywords
#
# `False, True, None, and, as, assert, async, await, def, del, elif, else, break, class, continue, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield`
#
# To check a variable's type, use the `type()` function.

# %%
type(university_facts)

# %% [markdown]
# # Basic math operators in Python
#
# Python supports standard arithmetic operations such as addition, subtraction, multiplication, and division. A list of basic math operators is below. For more details, refer to Python's documentation on **[math](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex)** operators.
#
# | **Operation**          | **Expression**           |   **Result**     |
# | :----------| :-------- | :-------- |
# | **Addition** | x + y     | Sum of x and y     |
# | **Subtraction** | x - y       | Difference of x and y       |
# | **Multiplication** | x * y       | Product of x and y     |
# | **Division** | x / y | Quotient of x and y      |
# | **Floor Division** | x // y       | Quotient rounded down     |
# | **Modulus** | x % y    | Remainder of x divided by y     |
# | **Exponention** | x ** y    | x raised to the power of y     |
# | **Negation** |-x      | Negative value of x    |
# | **Absolute Value**| abs(x)  | Absolute value of x |
# | **Convert to Int**| int(x)  | Converts x to an integer |
# | **Convert to Float**| float(x) | Converts x to a float |
# | **Power Function**| pow(x,y) | Equivalent to x ** y |
#
# **Example:**

# %%
x=10
y=15
z=x+y
print(z)

# %% [markdown]
# ```{admonition} Exercise 6: Find data type
# :class: sidebar note
# :icon: False
# Find the data type for the variable institution name
#
# ```

# %%
#execute code for Exercise 6 here
