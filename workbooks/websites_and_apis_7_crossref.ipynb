# %% [markdown]
# # DOIs & Data: Exploring Crossref Metadata with Python
#
# Lesson 7 of our Web Scraping and APIs for Digital Research workshop series explores Crossref, a nonprofit organization that manages the global registry of Digital Object Identifiers (DOIs). This session introduces the Crossref REST API, along with two essential Python tools: JSON for handling structured data, and logging for tracking and debugging your code.
#
# Using real-world examples, you’ll learn how to:
# - Query the Crossref API to retrieve metadata for journal articles, books, and more
# - Parse and work with JSON data in Python
# - Use Python’s built-in logging module to monitor your code and handle errors gracefully
#
# ## Data skills | concepts
# - APIs
# - logging
# - JSON data
#
# ## Learning objectives
# 1. Interpret documentation and apply concepts to write functional code.
# 2. Extract and work with JSON data using Python’s built-in tools.
# 3. Use Python’s logging module to capture and report errors that interrupt code execution.

# %% [markdown]
# # Crossref
#
# Crossref provides detailed __[documentation](https://www.crossref.org/documentation/retrieve-metadata/rest-api/)__ and a wide range of robust __[learning resources](https://www.crossref.org/learning/)__ to help users effectively work with its REST API.
#
# ## JSON
# Crossref queries return data in JSON format, which is easy to read and looks similar to Python dictionaries. You can work with JSON data by looping through its key-value pairs to access the information you need.
#
# ## EXERCISE 1: Crossref API
#
# Read through the __[Crossref REST API documentation](https://www.crossref.org/documentation/retrieve-metadata/rest-api/)__. Then ...
#
# 1. Read `data/dois.csv` into a Pandas DataFrame
# 2. Use the **Crossref works API** to gather the following fields for each DOI:
# - `publisher`
# - `article_title`
# - `journal_title`
# - `journal_abbr`
# - `year`
# - `reference count`

# %% [markdown]
# ## Logging
#
# APIs sometimes return [error codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) which interrupt our program's execution. Logging tells Python how to handle these errors. It can also help to identify issues with your code.
#
# ________________________________________
# ## 💡TIP: Copilot
# ![microsoft_copilot_icon](../images/microsoft_copilot_icon.svg "Decorative")\
# Ask Copilot how to  `handle exceptions in logging module`. Copilot will return code you can modify for your project and provide additional tips.
# ________________________________________
#
# ## EXERCISE 2: Handling exceptions
#
# Modify code from EXERCISE 1 to add a function that logs and handles HTTP Errors for bad responses.
