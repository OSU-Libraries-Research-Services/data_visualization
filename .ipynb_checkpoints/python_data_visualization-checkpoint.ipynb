# %% [markdown]
# ---
# title: Visualizing Data
# license: CC-BY-4.0
# github: https://github.com/OSU-Libraries-Research-Services/data_visualization
# subject: Tutorial
# authors:
#   - name: Sarah Anne Murphy
#     orcid: 0000-0002-7787-6890
#     affiliations:
#       - The Ohio State University Libraries
# date: 2025-06-09
# output_stderr: remove
# ---

# %% [markdown]
# 🚧 THIS PAGE IS UNDER CONSTRUCTION
#
# ## Data skills | concepts
# - Pandas
# - plotly
# - Seaborn
#
# ## Learning objectives
# 1.
# 2.
# 3.
#
#
#
# # Pandas
# __[Pandas](https://pandas.pydata.org/docs/reference/index.html)__ is powerful Python library designed to help you organize, explore and analyze in tables using Python. Pandas can be used to generate summary statistics and build basic visualizations.
#
# Pandas integrates with Matplotlib to generate simple plots using the `.plot()` method. The `kind =` parameter specifies the type of chart to create:
#
# | **kind =** | **Chart Type                                 |
# |:-------------------:|:-----------------------------------:|
# | `line`              | line chart (default)                |
# | `bar` or `barh`     | vertical or horizontal bar chart    |
# | `hist`              | histogram                           |
# | `box`               | boxplot                             |
# | `kde` or `density`  | Kernel Denstity Estimation plot     |
# | `area`              | area plot                           |
# | `scatter`           | scatterplot                         |
# | `hex`               | hexagonal bin plots                 |
# | `pie`               | pie charts                          |
#
#
# ## 📊 Bar Chart
# Let's build a bar chart that highlights the **average U.S. peak chart positions** for albums by __[2025 Rock & Roll Hall of Fame inductees](https://en.wikipedia.org/wiki/List_of_Rock_and_Roll_Hall_of_Fame_inductees)__ to explore visualizing data with Pandas.{sup}`^~`
#
# The syntax for building a __[Basic Pandas Chart](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot)__ is:
#
# `DataFrame.plot(*args, **kwargs)`
#
# ### Step 1. Import libraries
#
# Pandas works alongside matplotlib libraries to visualize data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Read in files
# We’ll use the `rock_n_roll_performers.csv` table from the Wikipedia page on __[Rock and Roll Hall of Fame inductees](https://en.wikipedia.org/wiki/List_of_Rock_and_Roll_Hall_of_Fame_inductees)__ to explore plotting with Pandas. The *Performers* category honors recording artists and bands who have had a significant and lasting impact on the development and legacy of rock and roll. We'll also enhance our analysis by linking this dataset with `rock_n_roll_studio_albums.csv`  which contains studio album information of many of the inductees.
#
# #### .read_csv()

# %%
performers=pd.read_csv('data/rock_n_roll_performers.csv', encoding="utf-8")

# A UnicodeDecodeError occurs after asking Pandas to read in rock_n_roll_studio_albums. Co-pilot suggests trying a difference encoding, like latin1
studio_albums=pd.read_csv('data/rock_n_roll_studio_albums.csv', encoding='latin1')

# %% [markdown]
# ### Step 2. Merge datasets
# After loading the **performers** and **studio_albums** tables using `pd.read_csv`, we can inspect the column headers using `.columns`.

# %%
performers.columns
# Out:
# Index(['index', 'year', 'image', 'name', 'inducted_members',
#        'prior_nominations', 'induction_presenter', 'artist', 'image_url',
#        'artist_url'],
#       dtype='object')

# %%
studio_albums.columns
# Out:
# Index(['index', 'album_title', 'artist', 'certification_aria',
#        'certification_aria_status', 'certification_aria_x',
#        'certification_bmvi', 'certification_bmvi_status',
#        'certification_bmvi_x', 'certification_bpi', 'certification_bpi_status',
#        'certification_bpi_x', 'certification_mc', 'certification_mc_status',
#        'certification_mc_x', 'certification_riaa', 'certification_riaa_status',
#        'certification_riaa_x', 'certification_snep',
#        'certification_snep_status', 'certification_snep_x', 'day',
#        'format_4_track', 'format_8_track', 'format_blueray', 'format_box_set',
#        'format_cassette', 'format_cd', 'format_digital_compact_cassette',
#        'format_digital_download', 'format_dvd', 'format_lp',
#        'format_mini_disc', 'format_picture_disc', 'format_reel',
#        'format_streaming', 'format_vhs', 'month', 'peakAUS', 'peakAUT',
#        'peakCAN', 'peakFRA', 'peakGER', 'peakIRE', 'peakITA', 'peakJPN',
#        'peakNLD', 'peakNOR', 'peakNZ', 'peakSPA', 'peakSWE', 'peakSWI',
#        'peakUK', 'peakUS', 'peakUS Country', 'peakUS R&B', 'Record label',
#        'Release date', 'year'],
#       dtype='object')

# %% [markdown]
# Both datasets share the columns **artist** and **year**, which could be used for merging. However, to avoid confusion after joining, we'll first rename the header **year** in the **performers** dataset to **year_inducted**.
#
# #### .rename()

# %%
performers=performers.rename(columns={'year':'year_inducted'})  
performers.columns
# Out:
# Index(['index', 'year_inducted', 'image', 'name', 'inducted_members',
#        'prior_nominations', 'induction_presenter', 'artist', 'image_url',
#        'artist_url'],
#       dtype='object')

# %% [markdown]
# Then, we'll merge the two datasets using the shared **artist** column.

# %%
performers_albums=pd.merge(performers, studio_albums, on='artist')
performers_albums.columns
# Out:
# Index(['index_x', 'year_inducted', 'image', 'name', 'inducted_members',
#        'prior_nominations', 'induction_presenter', 'artist', 'image_url',
#        'artist_url', 'index_y', 'album_title', 'certification_aria',
#        'certification_aria_status', 'certification_aria_x',
#        'certification_bmvi', 'certification_bmvi_status',
#        'certification_bmvi_x', 'certification_bpi', 'certification_bpi_status',
#        'certification_bpi_x', 'certification_mc', 'certification_mc_status',
#        'certification_mc_x', 'certification_riaa', 'certification_riaa_status',
#        'certification_riaa_x', 'certification_snep',
#        'certification_snep_status', 'certification_snep_x', 'day',
#        'format_4_track', 'format_8_track', 'format_blueray', 'format_box_set',
#        'format_cassette', 'format_cd', 'format_digital_compact_cassette',
#        'format_digital_download', 'format_dvd', 'format_lp',
#        'format_mini_disc', 'format_picture_disc', 'format_reel',
#        'format_streaming', 'format_vhs', 'month', 'peakAUS', 'peakAUT',
#        'peakCAN', 'peakFRA', 'peakGER', 'peakIRE', 'peakITA', 'peakJPN',
#        'peakNLD', 'peakNOR', 'peakNZ', 'peakSPA', 'peakSWE', 'peakSWI',
#        'peakUK', 'peakUS', 'peakUS Country', 'peakUS R&B', 'Record label',
#        'Release date', 'year'],
#       dtype='object')

# %% [markdown]
# ### Step 3. Create and apply filters
# Now that we’ve merged the inductee and album datasets, we can begin filtering the data to focus on specific trends or groups.
#
# Before applying any filters, it’s important to confirm the data type of the **year_inducted** column in the **performers_albums** DataFrame. This ensures we can perform numerical comparisons or sorting without errors.
#
# #### .dtypes

# %%
performers_albums['year_inducted'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# We can create and apply **filter** to isolate the **2025 inductees** using the **year_inducted** field.
#
# #### filter_variable=df['column']==value

# %%
#First create the filter
_2025_inductees= performers_albums['year_inducted']==2025

# %% [markdown]
# #### filtered_df=df[filter_variable]

# %%
#Then apply the filter
performers_albums_filtered=performers_albums[_2025_inductees]
performers_albums_filtered
# Out:
#       index_x  year_inducted  image                    name  \
# 4770      264           2025    NaN        Bad Company[193]
# 4771      264           2025    NaN        Bad Company[193]
# 4772      264           2025    NaN        Bad Company[193]
# 4773      264           2025    NaN        Bad Company[193]
# 4774      264           2025    NaN        Bad Company[193]
# ...       ...            ...    ...                     ...
# 4846      270           2025    NaN  The White Stripes[193]
# 4847      270           2025    NaN  The White Stripes[193]
# 4848      270           2025    NaN  The White Stripes[193]
# 4849      270           2025    NaN  The White Stripes[193]
# 4850      270           2025    NaN  The White Stripes[193]
#
#                                        inducted_members prior_nominations  \
# 4770  Boz Burrell, Simon Kirke, Mick Ralphs, and Pau...  First nomination
# 4771  Boz Burrell, Simon Kirke, Mick Ralphs, and Pau...  First nomination
# 4772  Boz Burrell, Simon Kirke, Mick Ralphs, and Pau...  First nomination
# 4773  Boz Burrell, Simon Kirke, Mick Ralphs, and Pau...  First nomination
# 4774  Boz Burrell, Simon Kirke, Mick Ralphs, and Pau...  First nomination
# ...                                                 ...               ...
# 4846                Jack White and Meg White.[197][198]          1 (2023)
# 4847                Jack White and Meg White.[197][198]          1 (2023)
# 4848                Jack White and Meg White.[197][198]          1 (2023)
# 4849                Jack White and Meg White.[197][198]          1 (2023)
# 4850                Jack White and Meg White.[197][198]          1 (2023)
#
#      induction_presenter             artist  \
# 4770                 NaN        Bad Company
# 4771                 NaN        Bad Company
# 4772                 NaN        Bad Company
# 4773                 NaN        Bad Company
# 4774                 NaN        Bad Company
# ...                  ...                ...
# 4846                 NaN  The White Stripes
# 4847                 NaN  The White Stripes
# 4848                 NaN  The White Stripes
# 4849                 NaN  The White Stripes
# 4850                 NaN  The White Stripes
#
#                                            image_url               artist_url  \
# 4770               /wiki/File:Bad_Company_-_1976.jpg        /wiki/Bad_Company
# 4771               /wiki/File:Bad_Company_-_1976.jpg        /wiki/Bad_Company
# 4772               /wiki/File:Bad_Company_-_1976.jpg        /wiki/Bad_Company
# 4773               /wiki/File:Bad_Company_-_1976.jpg        /wiki/Bad_Company
# 4774               /wiki/File:Bad_Company_-_1976.jpg        /wiki/Bad_Company
# ...                                              ...                      ...
# 4846  /wiki/File:Jack_%26_Meg,_The_White_Stripes.jpg  /wiki/The_White_Stripes
# 4847  /wiki/File:Jack_%26_Meg,_The_White_Stripes.jpg  /wiki/The_White_Stripes
# 4848  /wiki/File:Jack_%26_Meg,_The_White_Stripes.jpg  /wiki/The_White_Stripes
# 4849  /wiki/File:Jack_%26_Meg,_The_White_Stripes.jpg  /wiki/The_White_Stripes
# 4850  /wiki/File:Jack_%26_Meg,_The_White_Stripes.jpg  /wiki/The_White_Stripes
#
#       ...  peakSPA peakSWE peakSWI peakUK  peakUS peakUS Country peakUS R&B  \
# 4770  ...      NaN     NaN     NaN    3.0     1.0            NaN        NaN
# 4771  ...      NaN     NaN     NaN    3.0     3.0            NaN        NaN
# 4772  ...      NaN    23.0     NaN    4.0     5.0            NaN        NaN
# 4773  ...      NaN    32.0     NaN   17.0    15.0            NaN        NaN
# 4774  ...      NaN     9.0     NaN   10.0     3.0            NaN        NaN
# ...   ...      ...     ...     ...    ...     ...            ...        ...
# 4846  ...      NaN     NaN     NaN  137.0     NaN            NaN        NaN
# 4847  ...      NaN    53.0     NaN   55.0    61.0            NaN        NaN
# 4848  ...      NaN     7.0     NaN    1.0     6.0            NaN        NaN
# 4849  ...      NaN     8.0     NaN    3.0     3.0            NaN        NaN
# 4850  ...      NaN     9.0     NaN    1.0     2.0            NaN        NaN
#
#                                            Record label Release date  year
# 4770                                  Island, Swan Song    5/24/1974  1974
# 4771                                  Island, Swan Song    3/28/1975  1975
# 4772                                  Island, Swan Song    1/30/1976  1976
# 4773                                  Island, Swan Song     3/3/1977  1977
# 4774                                          Swan Song     3/7/1979  1979
# ...                                                 ...          ...   ...
# 4846                   Sympathy for the Record Industry    6/20/2000  2000
# 4847  Sympathy for the Record Industry, Third Man Re...     7/3/2001  2001
# 4848                                                 V2     4/1/2003  2003
# 4849                                                 V2     6/7/2005  2005
# 4850                            Third Man, Warner Bros.    6/15/2007  2007
#
# [81 rows x 68 columns]

# %% [markdown]
# ### Step 4. Aggregate data
#
# Pandas supports __[basic summary statistics](https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html)__
# with the following methods.
#
# | **calculation** | **description**                                    |
# |:--------------:|:-----------------------------------:|
# | `.count()`     | number of observations    |
# | `.sum()`       | histogram                           |
# | `.mean()`      | boxplot                             |
# | `.medium()`    | density plots                       |
# | `.min()`       | area plots                          |
# | `.max()`       | scatterplots                        |
# | `mode()`       | hexagonal bin plots                 |
# | `std()`        | pie charts                          |
#
# For this project, however, we must tell Pandas how to **group** the data before calculating the summary statistics.
#
# #### .groupby()

# %% [markdown]
# __[Aggregating statistics grouped by category](https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html#aggregating-statistics-grouped-by-category)__
# .groupby
#
# ### Step 5. Plot
# plots
#
#
#
# ---
# {sup}`^ Visit the Websites and APIs. __[Lesson 3. Wikipedia](https://osu-libraries-research-services.github.io/data_visualization/wikipedia)__ tutorial to learn how to extract tables from HTML using pandas.read_html.`\
# {sup}`~ See the __[Websites and APIs. Lesson 4. iCite](https://osu-libraries-research-services.github.io/data_visualization/icite)__ tutorial and __[Websites and APIs. Lesson 7. Crossref](https://osu-libraries-research-services.github.io/data_visualization/crossref)__ tutorial to learn how to use APIs to gather data.`

# %%
import pandas as pd
import matplotlib.pyplot as plt 
#read in rock_n_roll_performers.csv and rock_n_roll_studio_albums.csv

performers=pd.read_csv('data/rock_n_roll_performers.csv', encoding="utf-8")
performers=performers.rename(columns={'year':'year_inducted'})

# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb0 in position 4: invalid start byte
# Ask copilot how to fix this error. Co-pilot suggests trying a difference encoding, like latin1
studio_albums=pd.read_csv('data/rock_n_roll_studio_albums.csv', encoding='latin1')

#merge datasets
data=pd.merge(performers, studio_albums, on='artist')

#filter by 2025 inductees
_2025_inductees=data['year_inducted']==2025
filtered_data=data[_2025_inductees]

# %%
filtered_data.groupby('artist')['peakUS'].mean().sort_values(ascending=False).plot(kind='bar', xlabel="", title='Peak US Chart Position: \n 2025 Rock N Roll Hall of Fame Inductees')
# Out:
# <Axes: title={'center': 'Peak US Chart Position: \n 2025 Rock N Roll Hall of Fame Inductees'}>
