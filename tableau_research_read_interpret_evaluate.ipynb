# %% [markdown]
# ---
# title: Lesson 3. Read, Interpret, and Evaluate Data
# github: https://github.com/OSU-Libraries-Research-Services/data_visualization
# subject: Tutorial
# authors:
#   - name: Sarah Anne Murphy
#     orcid: 0000-0002-7787-6890
#     affiliations:
#       - The Ohio State University Libraries
# date: 2025-06-26
# output_stderr: remove
# bibliography:
#   - references.bib
#
#
# ---

# %% [markdown]
# 🚧 THIS PAGE IS UNDER CONSTRUCTION
#
# Lesson 2 introduced basic charts for comparing categorical values, visualizing trends over time, and exploring relationships within data. It also explored the distinction between **discrete** and **continuous** dates in Tableau and introduced **text tables** and **callout numbers** to emphasize key insights. This lesson introduces additional basic charts and techniques.
#
# ## Data skills | concepts
# - Tableau
# - Working with data
# - Analyzing data
#
# ## Learning objectives
#
# 1. Create groups to normalize data, correct errors, and simplify categories.
# 2. Apply hierarchies for better data organization.
# 3. Use formatting strategically to enhance visual impact.
# 4. Analyze data with table calculations.
# 5. Visualize part-to-whole relationships effectively.
#
# This tutorial is designed to support a multi-session __[Tableau for Research](https://library.osu.edu/events?tid=921)__ workshop hosted by The Ohio State University Libraries Research Commons. It is intended to help the **ABSOLUTE** beginner, or anyone who is relatively new to Tableau to build the skills and confidence to apply Tableau to research projects.

# %% [markdown]
# # LESSON 3
#
# ## Why Practice Matters
#
# Data visualization is a craft. Like any creative discipline, mastering this craft requires exposure to a variety of styles, techniques, and best practices. Just as musicians or artists grow by studying different genres, data visualiers improve by analyzing a wide range of visual storytelling examples.
#
# To sharpen your skills, make it a habit to explore and critically evalute real-world visualizations—both successful and flawed.
#
# ### Inspiration and Examples
# - __[Tableau Public Viz of the Day](https://public.tableau.com/app/discover/viz-of-the-day)__
# - __[FlowingData](https://flowingdata.com/category/visualization/)__
#
# ### Explore Data Journalism
# Major news outlets often feature compelling data visualizations created by professional data journalists. Check out examples from:
# - __[CNN](https://www.cnn.com/)__
# - __[The New York Times](https://usg.osu.edu/resources/initiatives/new-york-times-subscription)__
# - __[The Washington Post](https://search.library.osu.edu/permalink/01OHIOLINK_OSU/f8hd36/alma991085430073408507)
#
# ## The DRAMA Framework
#
# The **__[DRAMA Framework](https://www.librarianyarns.com/drama-source-eval#:~:text=DRAMA%20stands%20for%20Date%2C%20Relevance,in%20a%20one%20shot%20session.)__** —first introducted in Lesson 1—is also useful for critically evaluating data visualizations. It prompts you to consider key questions about the source and integrity of the visual.
#
# - **Who** created the visualization, and what was their purpose?
# - **How** was the underlying data collected, stored, and processed?
# - Are there any **biases or limitations** asknowledged or disclosed?
# - **When** was the visualization last updated, and is it still relevant?
#
# Using the DRAMA framework helps ensure that the visualizations you interpret—or create—are accurate, transparent, and meaningful within their context.

# %% [markdown]
# ## Groups and Hierarchies
#
# **Grouping data** is a powerful way to clean and organize your dataset. It allows you to:
#
# - **Normalize values –** Combine similar entries to ensure consistency (e.g., merging “OH” and “Ohio”).
# - **Correct errors –** Fix inconsistencies or typos in category names.
# - **Simplify categories –** Consolidate detailed values into broader, more meaningful groups.
#
# :::{tip} Multiple ways to accomplish a task!!!
# ![tableau_icon](images/tableau_logo.svg "Decorative")
#
#
# Groups are another great example where there more than one way to accomplish the same task!!!
# :::
#
# The simpliest way to create a group in Tableau is to:
#
# 1. **Select one or more data points** directly in the view.
# 2. **Click the paperclip icon** 📎 that appears in the tooltip.
#
# :::{admonition} Exercise 1. Group data
# :class: sidebar note
# :icon: False
#
# Create a text table showing the **peak US chart positions** for albums by five of your favorite artists.
#
# 1. **Start a new worksheet** and rename it **FavoriteArtistAlbum**.
# 2. **Select the relevant fields:**
#     - Drag **Artist** to the **Rows shelf**.
#     - Place ***Peak US** on the **Columns shelf**.\
# ![](images/tableau_show_me.png "Show Me icon")
# 3. Open **Show Me** and select **Text Tables**.
# 4. **Select your top 5 favorite artists:**
#     - Click on your first favorite artist
#     - Hold **Ctrl** (or **Cmd** on Mac) and to select the others.
# 5. **Click the paperclip icon 📎** on the **tooltip** for the last artist selected.
# 6. **Rename the group:**
#     - Right-click the first artist
#     - Select **Edit Alias**
#     - Rename to **Favorite artists**.
# 7. Right-click **Favorite artists** and choose **✔ Keep only**.
# 8. **Adjust fields:**
#     - Drag **Artist** to the **Rows shelf**
#     - Remove **Favorite artists** from the **Rows shelf**
#     - Drag **album_title** to the **Rows shelf**.
#
#
# :::
#
# :::{seealso} Solution
# :class: dropdown
#
# INSERT SOLUTION HERE
#
# :::
#
# A second way to create a group in Tableau is to:
# 1. **Right-click** a dimension or measure in the **Data Pane**
# 2. Select **Create > Group**.
#
# :::{admonition} Exercise 2. Group data
# :class: sidebar note
# :icon: False
#
# Use the Data Pane to group 10 of your **Favorite albums** into a single group.
#
# :::

# %% [markdown]
# ## Supplemental Readings
# ::::{grid} 1 1 2 3
#
# :::{card}
# :header: Effective Data Visualization
# ![](images/cover_evergreen.png "Decorative book cover")
# +++
# __[Effective Data Visualization](https://search.library.osu.edu/permalink/01OHIOLINK_OSU/rr4vai/alma991049294199708507)__ \
# by Stephanie Evergreen\
# Thousand Oaks, California: SAGE Publications, 2020.
# :::
#
# :::{card}
# :header: Better Data Visualizations
# ![](images/cover_schwabish_data_visualization.png "Decorative book cover")
# +++
# __[Better Data Visualizations](https://search.library.osu.edu/permalink/01OHIOLINK_OSU/rr4vai/alma991085487354008507)__ \
# by Jonathan Schwabish\
# New York: Columbia University Press, 2021.
# :::
#
# ::::
#
# - **Chapter 6:** “When There are Parts of a Whole:  Visualizing Beyond the Pie Chart.” In Evergreen, Stephanie. __[Effective Data Visualization: The Right Chart for the Right Data, 2nd edition](https://search.library.osu.edu/permalink/01OHIOLINK_OSU/rr4vai/alma991049294199708507)__ Effective Data Visualization: The Right Chart for the Right Data, 2nd edition. Thousand Oaks, California: SAGE Publications, 2020.
# - **Chapter 9:** “Part-to-Whole.” In Schwabish, Jonathan. __[Better Data Visualizations: A Guide for Scholars, Researchers, and Wonks](https://search.library.osu.edu/permalink/01OHIOLINK_OSU/rr4vai/alma991085487354008507)__. New York: Columbia University Press, 2021.
